# %% [markdown]
# <a href="https://colab.research.google.com/github/ValenzuelaJesus99/ValenzuelaJesus99.github.io/blob/main/RIFE_Video_Interpolation_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RIFE Video Interpolation Colab
#
# Adapted from: [ECCV2022-RIFE](https://github.com/megvii-research/ECCV2022-RIFE)
#
# Made with ❤️ by: [yuvraj108c](https://github.com/yuvraj108c)

# %% [markdown]
# # 1. Setup (~ 1 minute)

# %%
# !pip install gdown==v4.6.3
# !git clone https://github.com/hzwer/arXiv2020-RIFE

# !mkdir /content/arXiv2020-RIFE/train_log
# %cd /content/arXiv2020-RIFE/train_log
# !gdown 1APIzVeI-4ZZCEuIRE1m6WYfSCaOsi_7_
!7z e RIFE_trained_model_v3.6.zip

# %cd /content/arXiv2020-RIFE/
# !gdown 1i3xlKb7ax7Y70khcTcuePi6E7crO_dFc
# !pip install scikit-video
# Out:
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.2.0
#     Uninstalling gdown-5.2.0:
#       Successfully uninstalled gdown-5.2.0
# ...
# Cloning into 'arXiv2020-RIFE'...
# remote: Enumerating objects: 2037, done.
# remote: Counting objects: 100% (400/400), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 2037 (delta 364), reused 302 (delta 302), pack-reused 1637 (from 2)
# Receiving objects: 100% (2037/2037), 4.12 MiB | 18.02 MiB/s, done.
# Resolving deltas: 100% (1292/1292), done.
# /content/arXiv2020-RIFE/train_log
# Downloading...
# From: https://drive.google.com/uc?id=1APIzVeI-4ZZCEuIRE1m6WYfSCaOsi_7_
# To: /content/arXiv2020-RIFE/train_log/RIFE_trained_model_v3.6.zip
# 100% 11.3M/11.3M [00:00<00:00, 26.5MB/s]
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# ...

# %% [markdown]
# # 2. Interpolate video
#
# - Upload your video & set the video path
# - Adjust the `exp` slider, which controls the FPS of the output video
# - The interpolated video will be saved in the same directory as original video

# %%
# --- Parche para np.float en sk-video ---
import sys
import types
import numpy as np

# Redefinir np.float
np.float = float

# Limpiar módulos ya importados que podrían usar np.float
for mod in list(sys.modules):
    if mod.startswith("skvideo"):
        del sys.modules[mod]

# Ahora skvideo se volverá a importar con el parche activo
# ---------------------------------------

# Configuración del video y del modelo
video_path = "/content/arXiv2020-RIFE/video.mp4"  #@param {type:"string"}
exp = 1  # @param {type:"slider", min:1, max:10, step:1}

# Ejecutar el script de inferencia
# !python3 /content/arXiv2020-RIFE/inference_video.py --exp={exp} --video={video_path}
# Out:
# Loaded v3.x HD model.
# Traceback (most recent call last):
#   File "/content/arXiv2020-RIFE/inference_video.py", line 125, in <module>
#     fpsNotAssigned = False
#             ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/skvideo/io/io.py", line 251, in vreader
#     reader = FFmpegReader(fname, inputdict=inputdict, outputdict=outputdict, verbosity=verbosity)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/skvideo/io/ffmpeg.py", line 44, in __init__
#     super(FFmpegReader,self).__init__(*args, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/skvideo/io/abstract.py", line 112, in __init__
#     self.inputwidth = np.int(viddict[self.INFO_WIDTH])
#                       ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/__init__.py", line 394, in __getattr__
#     raise AttributeError(__former_attrs__[attr])
# ...
